# %%
import urllib.request, json

url = "https://www.zillow.com/search/GetResults.htm?spt=homes&status=111001&lt=111101&ht=111111&pr=95000,310000&mp=374,1219&bd=1%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&condo-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-74085703,40205951,-73975840,40243436&p=1&sort=days&search=maplist&selrect=-74016180,40213031,-73993006,40233215&listright=true"

req = urllib.request.Request(url)

form_data = {
    "clipPolygon":"40.231512,-73.994207|40.231512,-74.002275|40.233215,-74.00588|40.233084,-74.009314|40.213031,-74.01618|40.215521,-74.005537|40.215652,-74.000044|40.217619,-73.996782|40.225614,-73.993349|40.229415,-73.993006|40.231381,-73.994379|40.231512,-73.994207|40.231512,-73.994207",
    "isMapSearch":"true",
    "zoom":"12"
}
form_data_encoded = urllib.parse.urlencode(form_data).encode('UTF-8')

req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:65.0) Gecko/20100101 Firefox/65.0')
req.add_header('Accept', '*/*')
req.add_header('Accept-Language', 'en-US,en;q=0.5')
req.add_header('Referer', 'https://www.zillow.com/homes/for_sale/1-_beds/95000-310000_price/374-1219_mp/40.243436,-73.97584,40.205951,-74.085703_rect/12_zm/1_rs/')
req.add_header('X-Requested-With', 'XMLHttpRequest')
req.add_header('Content-Type', 'application/x-www-form-urlencoded; charset=UTF-8')
req.add_header('DNT', '1')
req.add_header('Connection', 'keep-alive')
req.add_header('Cookie', 'abtest=2|Jx2NcYtu6ctloz0O; zguid=23|"%"2467fa6c30-e072-4aed-b9fa-223362c2a3bd; search=6|1554089456449"%"7Crect"%"3D40.243436"%"252C-73.97584"%"252C40.205951"%"252C-74.085703"%"26zm"%"3D12"%"26disp"%"3Dmap"%"26mdm"%"3Dauto"%"26p"%"3D1"%"26sort"%"3Ddays"%"26z"%"3D1"%"26beds"%"3D1-"%"26price"%"3D95000-310000"%"26mp"%"3D374-1219"%"26fs"%"3D1"%"26fr"%"3D0"%"26mmm"%"3D1"%"26rs"%"3D1"%"26ah"%"3D0"%"26singlestory"%"3D0"%"09"%"01"%"093455"%"09"%"09"%"092"%"090"%"09US_"%"09; G_ENABLED_IDPS=google; ajs_user_id=null; ajs_group_id=null; ajs_anonymous_id="%"2267fa6c30-e072-4aed-b9fa-223362c2a3bd"%"22; pxvid=0dfab0c0-23fa-11e9-b559-1fe0e5ced18e; _pxvid=0dfab0c0-23fa-11e9-b559-1fe0e5ced18e; zgsession=1|a498a39b-cef9-4b5c-9761-43be8820527a; AWSALB=IJV7QEbLzI2WNem2dALt1Vj90df1v4TQegFSWPWoyWM6Q5TvHyd6GAmprnitXqbseYnp9lzi5yC7GthmmInMYp0XAG9LCuHhB7kB+iuXfyYmDAZdLUYs9K5v9Qa/; JSESSIONID=E9F25B2FB35350619F786B886E766102; __tld__=1; _px3=8e27bebd3f0075d3c9ff1f98cff63725540f874c284c30c42568be0fb06fd6c1:eP13oqJ+rbwiZTBgXJh63Wfv/0n4kUk+fH4Z+cmXvRPylIaxmcKQKJk8qsRUh/hDR44jXPePpihIFcXbVyRbHQ==:1000:huJaOySqQZtVHnIu52rDCrfdYIkLmObdDiGyVFpct7QRv/s7N86mzCl5hDapEj8lT/Nes/fXLbWsbJ/6i90eW2LeIu8oME8aN2O7cRq0qN/oyh9T+t1ymS3Q8kqsNBDxPQ4bSevtQ/EhkeSY2FNnnrXhgd+dX0P8PpLETZ70Cug=; ajs"%"3Acookies=true; ajs"%"3Atest=true; _pxff_tm=1')
req.add_header('TE', 'Trailers')

response = urllib.request.urlopen(req, form_data_encoded)
data = response.read().decode("utf-8")
data_json = json.loads(data)
print (data_json)
# Out:
# {'list': {'page': 1, 'numPages': 5, 'binCounts': {'totalResultCount': 112, 'forSaleCount': 7, 'makeMeMoveCount': 0, 'recentlySoldCount': 106, 'forRentCount': 17, 'fsbaCount': 7, 'fsboCount': 0, 'foreclosuresCount': 0, 'bankOwnedCount': 0, 'foreclosedCount': 0, 'preForeclosureCount': 0, 'newConstructionCount': 0, 'openHousesCount': 0, 'singleFamilyCount': 15, 'condoCount': 91, 'multiFamilyCount': 6, 'manufacturedCount': 0, 'landCount': 0, 'unmappedCount': 0, 'comingSoonCount': 0}, 'numFavorites': 0, 'pagination': '&lt;ol class="zsg-pagination"&gt;&lt;li class="zsg-pagination_active"&gt;&lt;a&gt;1&lt;/a&gt;&lt;/li&gt;&lt;li&gt;&lt;a href="/homes/for_sale/182595c7adX1-CRq1772clolvum_z8f50_crid/1-_beds/95000-310000_price/374-1219_mp/0_singlestory/days_sort/40.243436,-73.97584,40.205951,-74.085703_rect/12_zm/2_p/1_rs/" onclick="SearchMain.changePage(2);return false;"&gt;2&lt;/a&gt;&lt;/li&gt;&lt;li&gt;&lt;a href="/homes/for_sale/182595c7adX1-CRq1772clolvum_z8f50_crid/1-_beds/95000-310000_
# ...

# %%
sites = (data_json['map']['properties'])
site_headers = [
    "zpid",
    "streetAddress",
    "zipcode",
    "city",
    "state",
    "latitude",
    "longitude",
    "price",
    "dateSold",
    "bathrooms",
    "bedrooms",
    "livingArea",
    "yearBuilt",
    "lotSize",
    "homeType",
    "homeStatus",
    "photoCount",
    "imageLink",
    "daysOnZillow",
    "isFeatured",
    "shouldHighlight",
    "brokerId",
    "isRentalWithBasePrice",
    "zestimate",
    "rentZestimate",
    "listing_sub_type",
    "priceReduction",
    "isUnmappable",
    "rentalPetsFlags",
    "mediumImageLink",
    "isPreforeclosureAuction",
    "homeStatusForHDP",
    "priceForHDP",
    "festimate",
    "isListingOwnedByCurrentSignedInAgent",
    "isListingClaimedByCurrentSignedInUser",
    "hiResImageLink",
    "watchImageLink",
    "tvImageLink",
    "tvCollectionImageLink",
    "tvHighResImageLink",
    "zillowHasRightsToImages",
    "desktopWebHdpImageLink",
    "hideZestimate",
    "isPremierBuilder",
    "isZillowOwned",
    "currency",
    "country",
]
site_matrix = []

for site in sites:
    site_values = []
    for header in site_headers:
        if header in site[8][11]:
            site_values.append(site[8][11][header])
        else:
            site_values.append(None)
    site_matrix.append(site_values)
    
print (site_matrix)
# Out:
# [[2146948569, '517 1st Ave', '07712', 'Asbury Park', 'NJ', 40.220681, -74.007218, 1425.0, 0, 1.0, 1.0, 700.0, -1, -1.0, 'MULTI_FAMILY', 'FOR_RENT', 7, 'https://photos.zillowstatic.com/p_g/ISmmv99n5xc6f51000000000.jpg', -1, False, False, 13668, False, 842477, 1600, {}, '', False, 67, 'https://photos.zillowstatic.com/p_c/ISmmv99n5xc6f51000000000.jpg', False, 'FOR_RENT', 1425.0, 716105, False, False, 'https://photos.zillowstatic.com/p_f/ISmmv99n5xc6f51000000000.jpg', 'https://photos.zillowstatic.com/p_j/ISmmv99n5xc6f51000000000.jpg', 'https://photos.zillowstatic.com/p_m/ISmmv99n5xc6f51000000000.jpg', 'https://photos.zillowstatic.com/p_l/ISmmv99n5xc6f51000000000.jpg', 'https://photos.zillowstatic.com/p_n/ISmmv99n5xc6f51000000000.jpg', False, 'https://photos.zillowstatic.com/p_h/ISmmv99n5xc6f51000000000.jpg', False, False, False, 'USD', 'USA', None], [2097526797, '304 4th Ave APT 304', '07712', 'Asbury Park', 'NJ', 40.222842, -74.003852, 250000.0, 0, 1.0, 1.0, None, -1, -1.0, 'CONDO', 'FO
# ...

# %%
import pandas as pd

df = pd.DataFrame(data=site_matrix,
          columns=site_headers)

print (df.groupby(['homeType', 'bedrooms','homeStatusForHDP']).mean()['price'])
# Out:
# homeType       bedrooms  homeStatusForHDP
# APARTMENT      2.0       RECENTLY_SOLD       201250.000000
# CONDO          1.0       FOR_SALE            274950.000000
#                          RECENTLY_SOLD       226523.809524
#                2.0       RECENTLY_SOLD       230000.000000
# MULTI_FAMILY   1.0       FOR_RENT              1512.500000
#                          RECENTLY_SOLD       200500.000000
#                4.0       RECENTLY_SOLD       301800.000000
# SINGLE_FAMILY  1.0       RECENTLY_SOLD       290000.000000
#                2.0       RECENTLY_SOLD       228600.000000
#                3.0       RECENTLY_SOLD       227200.000000
#                4.0       RECENTLY_SOLD       300000.000000
#                5.0       RECENTLY_SOLD       241000.000000
#                6.0       RECENTLY_SOLD       260000.000000
#                7.0       RECENTLY_SOLD       230000.000000
# Name: price, dtype: float64

# %%
summary_df = df[['latitude','longitude','price','homeStatusForHDP','bedrooms']].copy()
print (summary_df)
# Out:
#      latitude  longitude     price homeStatusForHDP  bedrooms
# 0   40.220681 -74.007218    1425.0         FOR_RENT       1.0
# 1   40.222842 -74.003852  250000.0         FOR_SALE       1.0
# 2   40.221469 -74.011210  299900.0         FOR_SALE       1.0
# 3   40.230026 -74.004707  276000.0    RECENTLY_SOLD       1.0
# 4   40.224030 -74.002827  295000.0    RECENTLY_SOLD       1.0
# 5   40.213270 -74.015929    1600.0         FOR_RENT       1.0
# 6   40.227810 -74.004875  185000.0    RECENTLY_SOLD       2.0
# 7   40.223813 -74.005971  302000.0    RECENTLY_SOLD       1.0
# 8   40.221490 -74.011202  285000.0    RECENTLY_SOLD       1.0
# 9   40.219643 -74.011054  301800.0    RECENTLY_SOLD       4.0
# 10  40.227270 -74.001007  171000.0    RECENTLY_SOLD       1.0
# 11  40.228549 -74.000204  288000.0    RECENTLY_SOLD       1.0
# 12  40.229430 -74.000160  230000.0    RECENTLY_SOLD       1.0
# 13  40.219147 -74.007854  230000.0    RECENTLY_SOLD       7.0
# ...

# %%
# Draw a leaflet map with all condos

import geopandas as gpd
from shapely.geometry import Point

# zip the lon and lat into a coordinates column
summary_df['Coordinates'] = list(zip(summary_df.longitude, summary_df.latitude))

# Now we can get rid of those lon and lat columns
summary_df.drop('longitude', axis=1, inplace=True)
summary_df.drop('latitude', axis=1, inplace=True)

# GeoPandas needs a Shapely geometry, so convert that lon,lat to a Point
summary_df['Coordinates'] = summary_df['Coordinates'].apply(Point)

gdf = gpd.GeoDataFrame(summary_df, geometry='Coordinates')
print (gdf)
# Out:
#        price homeStatusForHDP  bedrooms                           Coordinates
# 0     1425.0         FOR_RENT       1.0  POINT (-74.00721799999999 40.220681)
# 1   250000.0         FOR_SALE       1.0  POINT (-74.00385199999999 40.222842)
# 2   299900.0         FOR_SALE       1.0  POINT (-74.01121000000001 40.221469)
# 3   276000.0    RECENTLY_SOLD       1.0          POINT (-74.004707 40.230026)
# 4   295000.0    RECENTLY_SOLD       1.0           POINT (-74.002827 40.22403)
# 5     1600.0         FOR_RENT       1.0           POINT (-74.015929 40.21327)
# 6   185000.0    RECENTLY_SOLD       2.0           POINT (-74.004875 40.22781)
# 7   302000.0    RECENTLY_SOLD       1.0          POINT (-74.005971 40.223813)
# 8   285000.0    RECENTLY_SOLD       1.0           POINT (-74.011202 40.22149)
# 9   301800.0    RECENTLY_SOLD       4.0          POINT (-74.011054 40.219643)
# 10  171000.0    RECENTLY_SOLD       1.0           POINT (-74.001007 40.22727)
# ...

# %%
# Draw Path on a leaflet map

from ipyleaflet import Map, basemaps, basemap_to_tiles, GeoJSON, Popup
from ipywidgets import HTML
from shapely.geometry import shape, MultiPoint
import json
import math

# This isn't a ipyleaflet function for some reason!
def fitBounds(m, geojson):
    # Center the map on our shape!
    # Draw a buffer around the whole thing
    polygon = MultiPoint(list(map(lambda x: x['geometry']['coordinates'],geojson['features']))).convex_hull
    new_bounds = polygon.buffer(0.001).bounds
    new_center = [(new_bounds[1] + new_bounds[3]) / 2, (new_bounds[0] + new_bounds[2]) / 2]
    new_zoom = math.floor(
            min(math.log(180/(new_bounds[2] - new_bounds[0]), 2), math.log(360/(new_bounds[3] - new_bounds[1]), 2)))

    m.center = new_center
    m.zoom = new_zoom
    return m

m = Map(
    layers=(basemap_to_tiles(basemaps.CartoDB.DarkMatter), )
)

# There's got to be a better way to do popups!
out_data = json.loads(gdf.to_json())
popups = list(map(lambda x: Popup(child=HTML(value=x['properties']['homeStatusForHDP']),
                                  location=(x['geometry']['coordinates'][1],
                                            x['geometry']['coordinates'][0])),
                                  out_data['features']))

def click_handler(event=None, id=None, properties=None, type=None, coordinates=None):
    if (id):
        m.add_layer(popups[int(id)])
        
out_data = json.loads(gdf.to_json())
geo_json = GeoJSON(data=out_data, onEachLayer=(lambda x: print (x)))
geo_json.on_click(click_handler)

m.add_layer(geo_json)

m = fitBounds(m, out_data)


m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
